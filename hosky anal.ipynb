# %%
import pprintpp
import requests
import json
import time
import random


POLICY_ID = "a5bb0e5bb275a573d744a021f9b3bff73595468e002755b447e01559"
POLICY_ID_2 = "ec77283fe87b1ccd7e5e8eb963de4c90abc8488e1e090b16b7f70a50"

CHEF = "682fd73eea4d7370b6f7a781c80b1252817b23f74688cea6257471f3"
SALT = "ea90b56d9c4d04c583ec728c8b415948b310d4653d12bd281aaff9df"
A3C = "159bd971439653da2b97d12facae06ff5e6d7410d074edaab425202b"
PSB = "f2fa0dfea7f4caba8cbdd042c4940c783ee57f9516062725b04e19a3"
ITZA = "c29dd3c55a4f3f3b02aae6463ef8e1e66a70b5d000f8a6dc3430ef04"
ALLI = "e01133b97103bb932f7be0f7896ed1ca1d0ee350e4c8058e101b73d6"


HEADERS = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36",
"Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2919.83 Safari/537.36",
"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2866.71 Safari/537.36",
"Mozilla/5.0 (X11; Ubuntu; Linux i686 on x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2820.59 Safari/537.36"]



response = requests.get("https://pool.pm/stake/" + SALT)

wallets = response.json().keys()






l = [] 
i = 0


for i in wallets:
    l.append(str(i))
    


url_base = "https://api.koios.rest/api/v0/address_assets?_address="
l1 = []

for stake in l:
    l1.append(url_base + stake)
    
l1    
    
#l2 =[]
#wallet = 0
#cash_grab = 0
#weight_total = 0
#gnome = 0
#req_count = 0
#f = random.choice(HEADERS)
#
#for url in l1:
#    r1 = requests.get(url)
#    
#    while str(r1) != "<Response [200]>":
#        req_count += 1
#        if req_count == 100:
#            break
#    
#    rt = r1.text
#    for _ in range(1):
#        
#        cash_grab = rt.count(POLICY_ID)
#        gnome = rt.count(POLICY_ID_2)
#        weight_total += cash_grab + (gnome * 15)
#        
#        wallet += 1
#        #time.sleep(1)
#    print("Delegators analyzed: " + str(wallet) + "  Total Weight: ",weight_total,"  CG here: ",cash_grab, "  Gnome here: ", gnome)
# Out:
# ['https://api.koios.rest/api/v0/address_assets?_address=stake1u930cpy9glwpatjrjh3u07l8cf97zvwmchrqkl0fl4584tqp3052p',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1uymse6h96hccdku9fcv4wdtdkqu7pf5qdjfm7zp9uh9wkeqztztdj',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1u8hvag8wrp2cnqy49ckacz26m2sd023v9rx4r233ky9xh2skht25d',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1u92ynd4ymc6xxwuykv8e5ma4hwjyyhr9cshzcfmkxe0ckyguwqgee',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1u8vx7uyqj9wtalf6dtj8qqff0chgs47fd9fhvnwzstxrzysgzh0ka',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1uyglm29sphkd35h0lqtklm28jzphq4nu2f9ds89t4pv694c0rz28q',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1uy0lrk05tds8rw2gwszy9ef5npe0v542d3spc5ms47gmy6qmxkl32',
#  'https://api.koios.rest/api/v0/address_assets?_address=stake1u9fkp06ceajde2h3ck5akhgqukrnyje9yam9vcetqz2fljcyz3zdh',
# ...

# %%
POLICY_ID = "a5bb0e5bb275a573d744a021f9b3bff73595468e002755b447e01559"

response = requests.get("https://api.koios.rest/api/v0/address_info?_address=62fc048547dc1eae4395e3c7fbe7c24be131dbc5c60b7de9fd687aac")


content = response.json()

content

#print(content)

#content.count(POLICY_ID)
# Out:
# []
